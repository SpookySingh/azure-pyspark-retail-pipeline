# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Retail PySpark Pipeline") \
    .master("local[*]") \
    .getOrCreate()

spark
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       1 from pyspark.sql import SparkSession
#       3 spark = SparkSession.builder \
#       4     .appName("Retail PySpark Pipeline") \
#       5     .master("local[*]") \
# ----> 6     .getOrCreate()
#       8 spark
#
# File ~\Documents\Personal Projects\azure-pyspark-retail-pipeline\venv\Lib\site-packages\pyspark\sql\session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# ...
